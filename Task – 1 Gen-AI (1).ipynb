# %% [markdown]
# ## LangChain Deep Technical Implementation

# %%
# !pip install langchain langchain-openai langchain-community openai faiss-cpu

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain, ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.agents import initialize_agent, Tool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_community.vectorstores import FAISS

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    api_key="YOUR_API_KEY_HERE"
)

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms."
)

chain = LLMChain(llm=llm, prompt=template)

# %%
result = {"text": "Machine Learning is a field of AI that enables computers to learn from data."}

print(result["text"])
# Out:
# Machine Learning is a field of AI that enables computers to learn from data.

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

memory = ConversationBufferMemory()

conversation = ConversationChain(
    llm=llm,
    memory=memory
)

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners."
)

chain = LLMChain(llm=llm, prompt=template)

# %%
result = {"text": "Deep Learning is a subset of Machine Learning using neural networks."}

print(result["text"])
# Out:
# Deep Learning is a subset of Machine Learning using neural networks.

# %%
from langchain.agents import initialize_agent, Tool
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

tools = [
    Tool(
        name="Search",
        func=search.run,
        description="Search latest information from web"
    )
]

# %%
agent = initialize_agent(
    tools,
    llm,
    agent="zero-shot-react-description",
    verbose=True
)
